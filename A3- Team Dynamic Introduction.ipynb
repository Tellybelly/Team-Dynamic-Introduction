# %%
###### Team 9
#Juan Vives, Shantanu Behl, Cassius Hall,Ifeoluwa Ajala, Khoa Le, Krystel Lualhati
#A3 Team Dynamic Introduction


#introduction to the story by using print function 
#throughout the code we will repeately use the input() function to obtain the 
#users data and prompt to have the answer next to the question
#function print() will be used to show the user our instructions and results

print(f"""
{'-' * 40}


Hello!
We are team 9 and we would really like your help to get some information.
Also, please answer in lower case. 

{'-' * 40}\n""")



#prompt 1 
#asking to say hello in their particular languge using input to obtain data
#using .capitalize() to make it start with capital letter
#asking user for input
hello = input(prompt = 
              """What is Hello in your native language? """).capitalize()

#answering the user to engage by using print()
print(f"""{hello} to you too! 

{'-' * 40}\n""")

#prompt 2
#asking about their coding expectations, using input and prompt to obtain data
coding_expectations = input(prompt = 
"""What adjective would best describe your expectations about coding? (i.e. scary, challenging...) """)
#answerig the user to engage by using print()
print(f"""We were expecting it to be {coding_expectations} too!

{'-' * 40}\n""")

#prompt 3
#define the number of people in the team, for this we will use the following:
#input function and prompt 
number_people = input(prompt = """How many people are in your team? """)
#transforming the input variable to an integer by using int()
number_people  = int(number_people)
#printing out the answer of how many people were in the team by using print()
print(f"""{number_people}! That is our favourite number.


{'-' * 40}\n""")


#prompt 4
#define how many in your team knows how to code before hand,using input
people_coded = input(prompt = 
"""How many in your team knows how to code beforehand? """)
#transforming the input variable to an integer
people_coded = int(people_coded)
#defining a new variable to find out how many did not know how to code
people_no_coded = number_people - people_coded
#defining a new variable to find the % of how many knew before
#using round to limit the decimal places to two
percentage_coded = round(((people_coded/number_people)*100),2)
#showing the user a result with extra data by using print()
print(f"""Great! So {people_coded} did know how to code and {people_no_coded} that did not know before. 
That means that {percentage_coded}% knew to code beforehand.

{'-' * 40}\n""")

#prompt 5
#asking for input of opinion on past career
career_opinion = input(prompt = 
"""What is your opinion of your past career? (i.e. fun, challenging...)""")
#showing the user an answer by using print()
print(f"""What a coincidence! We also thought that our past careers were {career_opinion}, 
this is why we are learning how to code now.

{'-' * 40}\n""")

#prompt 6
#asking the users for input on past experience
life_before_hult = input(prompt = 
""""What were you doing before coming to Hult? (i.e.specify where working and position/studying...) """)
#answering the user by using print()
print(f"""It is so interesting that you were {life_before_hult}, 
we range from police dispatching to building Hot-Wheels! 

{'-' * 40}\n""")


#prompt 7
#asking user for input on opinion of entertainment 
entertainment = input(prompt = 
"""What kind of movies/tv shows do you like watching? (i.e. thriller, drama...)""")
#showing the user the answer
print(f"""We also like {entertainment} but we prefer true crime documentaries!

{'-' * 40}\n""")

#prompt 8
#asking user for input on sports preferences 
sports = input(prompt = 
"""What sports do you like playing? (i.e. soccer, basketball...)""")
#answering the user by using print()
print(f"""All sports are great but {sports} is super fun!

{'-' * 40}\n""")


#showing the user that all the inputs have been obtained and moving forwards
print(f"""Thank you for your time and answers!
Now that we have the information, we will proceed to the story.

{'-' * 40}\n""")

#showing the dynamic story to the user, using variables created before
print(f"""
{hello},
It could have been anybody else, but the {number_people} of us gathered 
to discover our skills in coding. We expected a {coding_expectations} start 
for this program, and we were right;from our discussion, we figured out that 
{people_coded} of us knew how to code, the other {people_no_coded} did not,
meaning that {percentage_coded}% knew how to code. Don’t get the wrong idea. 
All of us loved our previous careers – we got the coolest jobs before we 
decided to become future coders. Have you ever met someone who has done 
{life_before_hult}? Working life can be stressful, but we still restore 
work-life balance by watching {entertainment} or playing {sports}. We all 
enjoy these simple things in our own free time, and if you didn’t know, our 
team congratulates Cassius for watching their child grow.  

Nice meeting you all!

{'-' * 40}\n""")
# Out:
# ----------------------------------------
#
#
# Hello!
# We are team 9 and we would really like your help to get some information.
# Also, please answer in lower case.
#
# ----------------------------------------

# %% [markdown]
# Hello, Hola, Kóyo, Xin Chào, Namaste!
#
# It could have been anybody else, but the 6 of us gathered to discover our skills in coding. We expected a rough start for this program, and we were right; from our discussion, we figured out that 1 of us knew how to code, the other 5 did not. Don’t get the wrong idea. All of us loved our previous careers – we got the coolest jobs before we decided to become future coders. Have you ever met someone who has done ultrasound for cows, police dispatching, build Hotwheels, finance consultant, and marketer?  Working life can be stressful, but we still restore work-life balance by watching Asian dramas, crime documentaries, professional football, virtual reality or playing basketball, skating, video games and surfing. We all enjoy these simple things in our own free time, and if you didn’t know, our team congratulates Cassius for watching their child grow. 🤗
#
#
# Nice meeting you all!
#
# ♡ Love From,
# Juan Vives, Shantanu Behl, Cassius Hall,Ifeoluwa Ajala,
# Khoa Le, and Krystel Lualhati
